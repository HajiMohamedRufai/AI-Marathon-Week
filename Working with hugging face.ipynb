# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# print my current working directory
import os

print(os.getcwd())
# Out:
# /kaggle/working

# %%
# list my files
print(os.listdir())
# Out:
# ['.virtual_documents']

# %%
# List files in the current working directory
current_files = os.listdir(os.getcwd())
print(current_files)
# Out:
# ['.virtual_documents', 'transcription']

# %%
# !touch sample.txt
# !echo "Hello World" > sample.txt

# %%
# !ls
# Out:
# sample.txt

# %% [markdown]
# # Working with Hugging face

# %%
from huggingface_hub import HfApi
api = HfApi()
list(api.list_models(limit=10))
# Out:
# [ModelInfo(id='stabilityai/stable-diffusion-3.5-large', author=None, sha=None, created_at=datetime.datetime(2024, 10, 22, 7, 29, 57, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=112356, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=636, library_name='diffusers', tags=['diffusers', 'safetensors', 'text-to-image', 'stable-diffusion', 'en', 'arxiv:2403.03206', 'license:other', 'diffusers:StableDiffusion3Pipeline', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=635, siblings=None, spaces=None, safetensors=None),
#  ModelInfo(id='nvidia/Llama-3.1-Nemotron-70B-Instruct-HF', author=None, sha=None, created_at=datetime.datetime(2024, 10, 12, 2, 37, 13, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=114289, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=1192, library_name='transformers', tags=['transformers', 'safetensors', 'llama', 'text-generation', 'nvidia', 'llama3.1', 'conversational', 'en', 'dataset:nvidia/HelpSteer2', 'arxiv:2410.01257', 'arxiv:2405.01481', 'arxiv:2406.08673', 'base_model:meta-llama/Llama-3.1-70B-Instruct', 'base_model:finetune:meta-llama/Llama-3.1-70B-Instruct', 'license:llama3.1', 'autotrain_compatible', 'text-generation-inference', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=558, siblings=None, spaces=None, safetensors=None),
#  ModelInfo(id='genmo/mochi-1-preview', author=None, sha=None, created_at=datetime.datetime(2024, 10, 22, 7, 36, 3, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=0, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=531, library_name='mochi-1-preview', tags=['mochi-1-preview', 'video', 'text-to-video', 'en', 'license:apache-2.0', 'region:us'], pipeline_tag='text-to-video', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=531, siblings=None, spaces=None, safetensors=None),
#  ModelInfo(id='microsoft/OmniParser', author=None, sha=None, created_at=datetime.datetime(2024, 10, 7, 23, 32, 7, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=641, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=375, library_name='transformers', tags=['transformers', 'safetensors', 'blip-2', 'visual-question-answering', 'image-text-to-text', 'arxiv:2408.00203', 'license:mit', 'endpoints_compatible', 'region:us'], pipeline_tag='image-text-to-text', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=371, siblings=None, spaces=None, safetensors=None),
#  ModelInfo(id='black-forest-labs/FLUX.1-dev', author=None, sha=None, created_at=datetime.datetime(2024, 7, 31, 21, 13, 44, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=1307429, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=5837, library_name='diffusers', tags=['diffusers', 'safetensors', 'text-to-image', 'image-generation', 'flux', 'en', 'license:other', 'endpoints_compatible', 'diffusers:FluxPipeline', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=231, siblings=None, spaces=None, safetensors=None),
#  ModelInfo(id='deepseek-ai/Janus-1.3B', author=None, sha=None, created_at=datetime.datetime(2024, 10, 18, 4, 19, 26, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=6026, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=395, library_name='transformers', tags=['transformers', 'safetensors', 'multi_modality', 'muiltimodal', 'text-to-image', 'unified-model', 'any-to-any', 'arxiv:2410.13848', 'license:mit', 'endpoints_compatible', 'region:us'], pipeline_tag='any-to-any', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=205, siblings=None, spaces=None, safetensors=None),
#  ModelInfo(id='Freepik/flux.1-lite-8B-alpha', author=None, sha=None, created_at=datetime.datetime(2024, 10, 17, 15, 28, 13, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=7652, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=185, library_name='diffusers', tags=['diffusers', 'safetensors', 'flux', 'text-to-image', 'base_model:black-forest-labs/FLUX.1-dev', 'base_model:finetune:black-forest-labs/FLUX.1-dev', 'license:other', 'endpoints_compatible', 'diffusers:FluxPipeline', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=185, siblings=None, spaces=None, safetensors=None),
#  ModelInfo(id='stabilityai/stable-diffusion-3.5-large-turbo', author=None, sha=None, created_at=datetime.datetime(2024, 10, 22, 7, 32, 47, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=13678, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=182, library_name='diffusers', tags=['diffusers', 'safetensors', 'text-to-image', 'stable-diffusion', 'en', 'arxiv:2403.03206', 'license:other', 'diffusers:StableDiffusion3Pipeline', 'region:us'], pipeline_tag='text-to-image', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=182, siblings=None, spaces=None, safetensors=None),
#  ModelInfo(id='rhymes-ai/Allegro', author=None, sha=None, created_at=datetime.datetime(2024, 10, 16, 3, 29, 57, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=74, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=169, library_name='diffusers', tags=['diffusers', 'safetensors', 'text-to-video', 'en', 'arxiv:2410.15458', 'license:apache-2.0', 'region:us'], pipeline_tag='text-to-video', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=169, siblings=None, spaces=None, safetensors=None),
#  ModelInfo(id='CohereForAI/aya-expanse-8b', author=None, sha=None, created_at=datetime.datetime(2024, 10, 23, 6, 34, 13, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=2358, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=138, library_name='transformers', tags=['transformers', 'safetensors', 'cohere', 'text-generation', 'conversational', 'en', 'fr', 'de', 'es', 'it', 'pt', 'ja', 'ko', 'zh', 'ar', 'el', 'fa', 'pl', 'id', 'cs', 'he', 'hi', 'nl', 'ro', 'ru', 'tr', 'uk', 'vi', 'arxiv:2408.14960', 'arxiv:2407.02552', 'arxiv:2406.18682', 'arxiv:2410.10801', 'license:cc-by-nc-4.0', 'autotrain_compatible', 'text-generation-inference', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=138, siblings=None, spaces=None, safetensors=None)]

# %%
from huggingface_hub import HfApi
from transformers import AutoModel

api = HfApi()
modelId = "distilbert-base-uncased-finetuned-sst-2-english"

# Instantiate the AutoModel class
model = AutoModel.from_pretrained(modelId)

# Save the model
model.save_pretrained(save_directory=f"models/{modelId}")
print("Done")
# Out:
# Done

# %%
import sys

print(f"Python version: {sys.version}")
# !{sys.executable} -m pip --version
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# pip 24.0 from /opt/conda/lib/python3.10/site-packages/pip (python 3.10)

# %%
# !python --version
# !pip --version
# Out:
# Python 3.10.14
# pip 24.0 from /opt/conda/lib/python3.10/site-packages/pip (python 3.10)
