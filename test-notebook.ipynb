# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# print my current working directory
import os

print(os.getcwd())

# %%
# list my files
print(os.listdir())

# %%
# List files in the current working directory
current_files = os.listdir(os.getcwd())
print(current_files)

# %%
# !touch sample.txt
# !echo "Hello World" > sample.txt

# %%
# !ls

# %% [markdown]
# # Working with Hugging face

# %%
from huggingface_hub import HfApi
api = HfApi()
list(api.list_models(limit=10))

# %%
from huggingface_hub import HfApi
from transformers import AutoModel

api = HfApi()
modelId = "distilbert-base-uncased-finetuned-sst-2-english"

# Instantiate the AutoModel class
model = AutoModel.from_pretrained(modelId)

# Save the model
model.save_pretrained(save_directory=f"models/{modelId}")
print("Done")

# %%
import sys

print(f"Python version: {sys.version}")
# !{sys.executable} -m pip --version

# %%
# !python --version
# !pip --version

# %%
# Adding a file
# !touch sample.txt
# !echo "I want to test if this file will exist if I push this to github" > sample.txt

# %%
# !pwd
# !ls

# %%
print("This is an updated code at 06:27 am in 29 Oct 2024")

# %%
print("update again at 06:29")

# %%
# This is code from my normal local, the sample.txt file created in Kaggle is not pushed
# only the notebook is the one pushed to my github repo
# Here, if I say my gitub repo is the main github repo which is hosted in github
# Now let me create here a new file then push it
# ie I want a dataset created here to exist in my github repo
# then on there, in Kaggle I can import dataset if I have the url of github repo 
# with the file name
# I have already created with my UI sample.txt file with text
# "I am HajiMohamedRufai"

# I also want to see if I can pull this sample.txt dataset in my kaggle

# %%
print("Let me save this as a'Save version' in kaggle")
print("Not possible, so only push or pull")

# %%
# Let me add this line in kaggle, I dont what versions are being pushed, I guess it is version3

# %%
# So I got one thing when I push and save version, then automatically it increases version. Okay thanks
# but first with an error then next push it updates eg .. version 5 etc

# %%
# BUt Alhamdulillah now I got it right, also you cant figure it out all before you start

# %% [markdown]
# # Working with Hugging Faces
